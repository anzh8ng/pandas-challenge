# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# load CSV
csv_path = "Resources/2016-FCC-New-Coders-Survey-Data.csv"

# %%
# Read with pandas
coder_df = str(pd.read_csv(csv_path)
coder_df.head()
# Out:
# C:\Users\Dorisu\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (21,57) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# ...

# %%
# Inspect all columns
coder_df.dtypes
coder_df.describe()
# Out:
#                 Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# count  13613.000000      15380.000000      933.000000            635.000000
# mean      29.175421          0.061964        0.689175              0.584252
# std        9.017716          0.241097        0.463080              0.493239
# min       10.000000          0.000000        0.000000              0.000000
# 25%       23.000000          0.000000        0.000000              0.000000
# 50%       27.000000          0.000000        1.000000              1.000000
# 75%       33.000000          0.000000        1.000000              1.000000
# max       86.000000          1.000000        1.000000              1.000000
#
#        BootcampLoanYesNo  BootcampMonthsAgo  BootcampPostSalary  \
# count         934.000000         631.000000          330.000000
# mean            0.332976           9.055468        63740.506061
# std             0.471531          12.968035        26347.200265
# ...

# %%
# Extract only columns 0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
reduced_df = coder_df.iloc[:,[0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]

reduced_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  ChildrenNumber  \
# 0                NaN                 NaN                NaN             NaN
# 1                NaN                 NaN                NaN             NaN
# 2                NaN                 NaN                NaN             NaN
# 3                NaN                 NaN                NaN             NaN
# 4                NaN                 NaN                NaN             NaN
#
#                   CityPopulation  CodeEventBootcamp               CountryLive  \
# ...

# %%
# Change "0" to "No" and "1" to "Yes" in response columns
       
replace_list = ['HasChildren','AttendedBootcamp','BootcampFinish','BootcampLoanYesNo','BootcampRecommend','BootcampFullJobAfter','CodeEventBootcamp']
reduced_df[replace_list] = reduced_df[replace_list].replace({0:"No",1:"Yes"})

reduced_df.head()

for col in reduced_df:
     print(col, reduced_df[col].unique())
# Out:
# Age [28. 22. 19. 26. 20. 34. 23. 35. 33. 57. 47. nan 37. 31. 27. 29. 30. 32.
#  25. 44. 21. 24. 18. 39. 41. 43. 36. 40. 38. 16. 46. 15. 14. 50. 49. 45.
#  55. 51. 17. 53. 52. 48. 56. 42. 54. 58. 65. 59. 75. 61. 80. 62. 60. 66.
#  12. 11. 13. 63. 64. 70. 73. 69. 71. 68. 86. 10. 67. 72.]
# AttendedBootcamp ['No' nan 'Yes']
# BootcampFinish [nan 'Yes' 'No']
# BootcampFullJobAfter [nan 'No' 'Yes']
# BootcampLoanYesNo [nan 'No' 'Yes']
# BootcampPostSalary [    nan  45000.  75000.  50000.  60000.  40000.  58000.  30000.  87000.
#   28000.  68000.  71000.  90000.  41600.  80000.  48000. 131000. 110000.
#   70000.  52000.  36000.  42000.  85000. 107000. 137050.   9000.  72000.
#  100000.  25000.  82000.  65000.  33000.  53000.  55000. 104000.  35000.
#  150000.  95000.  78000.   6000. 105000.  54000. 114000.  92000.  86000.
#   51000.  77000.  38000.  57000.  76000.  61000.  59000. 112500. 106000.
#   50339.  66000.  81000. 120000. 115000.  62000.  15000. 145000.  27486.
# ...

# %%
# Calculate total number of respondents in survey
total_resp = len(reduced_df)
total_resp
# Out:
# 15620

# %%
# Extract rows corresponding only to people who attended a bootcamp
attended_df = reduced_df.loc[reduced_df['AttendedBootcamp']== 'Yes']
attended_df.head()
# Out:
#       Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93   32.0              Yes            Yes                   No
# 97   26.0              Yes            Yes                  Yes
# 130  41.0              Yes            Yes                  Yes
# 159  26.0              Yes            Yes                   No
# 188  24.0              Yes             No                  NaN
#
#     BootcampLoanYesNo  BootcampPostSalary BootcampRecommend  ChildrenNumber  \
# 93                 No                 NaN                No             NaN
# 97                 No             45000.0                No             NaN
# 130               Yes             75000.0               Yes             3.0
# 159                No                 NaN                No             NaN
# 188               Yes                 NaN                No             NaN
#
#                     CityPopulation CodeEventBootcamp  \
# 93   between 100,000 and 1 million               NaN
# ...

# %%
# Calculate average age of attendees
avg_age = round(attended_df["Age"].mean(),2)

# Calculate how many people attended a bootcamp
attendence = attended_df["AttendedBootcamp"].count()

# Calculate how many attendees hold degrees
#attended_df['SchoolDegree'].value_counts()
degreeslist = ["bachelor's degree","master's degree (non-professional)","professional degree (MBA, MD, JD, etc.)",
           "associate's degree","Ph.D."]

degrees = attended_df['SchoolDegree'].isin(degreeslist).sum()

# Count number of attendees who self-identify as male; female; or are of non-binary gender identification
#attended_df['Gender'].value_counts()
nb_list = ["genderqueer","trans","agender"]

nb_cnt = attended_df['Gender'].isin(nb_list).sum()
m_cnt = attended_df['Gender'].value_counts()['male']
f_cnt = attended_df['Gender'].value_counts()['female']

# Calculate percentage of respondents who attended a bootcamp
percentattend = round((attendence / total_resp) * 100,2)

# Calculate percentage of respondents belonging to each gender
gen_resp = attended_df['Gender'].notna().sum()

m_resp = round((m_cnt/gen_resp)*100,2)
f_resp = round((f_cnt/gen_resp)*100,2)
nb_resp = round((nb_cnt/gen_resp)*100,2)

# Calculate percentage of attendees with a school degree
dg_pct = round((degrees/attendence)*100,2)

# Calculate average post-bootcamp salary
avg_sal = round(attended_df['BootcampPostSalary'].mean(),0)
avg_sal
#print(avg_age,attendence)
# Out:
# 63741.0

# %%
# Create a new table consolodating above calculations
def as_currency(x):
        return '${:,.2f}'.format(x)
def as_percent(y):
    return "{0:.2f}%".format(y)

table_df = {"Total Surveyed":[total_resp], "Total Bootcamp Attendees":[attendence],
           "% attended bootcamp":as_percent(percentattend), "Avg. Age":[avg_age],"Has a degree":[dg_pct],"% Male":as_percent(m_resp),
           "% Female":as_percent(f_resp),"% Non Gender Specific":as_percent(nb_resp),
            "Average Post Bootcamp Salary": as_currency(avg_sal)}
pd.DataFrame(table_df)
# Out:
#    Total Surveyed  Total Bootcamp Attendees % attended bootcamp  Avg. Age  \
# 0           15620                       953               6.10%     31.07
#
#    Has a degree  % Male % Female % Non Gender Specific  \
# 0         66.84  59.54%   39.14%                 1.32%
#
#   Average Post Bootcamp Salary
# 0                   $63,741.00

# %%
# Improve formatting before outputting spreadsheet

# %%
# Export to Excel
export = pd.DataFrame(table_df)
export.to_excel("grp2_pandapt1.xlsx")
